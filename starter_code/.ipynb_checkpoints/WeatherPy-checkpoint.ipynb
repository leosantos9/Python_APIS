# %% [markdown]
# # WeatherPy - Leo Santos - Analysis
# ----
#
# ### Analysis
# #1 In terms of latitude and max temperature, as of Feb 23, 2019, data shows warmer temperatures mostly leaning below 20 degrees north latitude (tropic of cancer) and mainly below the equator (southern hemisphere). These observations follow expected behavior: summer in the south and winter in the north at the moment.
#
# #2 City latitude does not seem to explain humidity; there not seem to be a strong correlation between these two variables.  In fact, I confirmed a very low R2 via excel.  Interesting fact: as I run the model several times, there were a few times where one or two outliers at >100% appeared on the plot.  It will have hard to live in "Paita, Peru" where there is a 290% humidity!
#
# #3 Latitude and cloudiness don't show a strong correlation.  there are a couple of horizontal lines that could somehow group many cloudiness levels; however, it will give no signs of correlation.
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# using time module to include today's date stamp on certain items such as chart titles and filenames
t = time.strftime("%m_%d_%Y")

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
# initializing lists for extraction. also, initializing dataframe which will receive those lists. 
res = []
q = []
cy = []
cloud = []
co = []
date1 = []
hum = []
lat = []
long = []
xtemp = []
ws =[]
d = pd.DataFrame()


# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
# Loop through the list of cities and perform a request for data on each
#counter for data retrieval csv
i = 1 
output_path = ("data_retrieval.txt") #initializing csv path for data retrieval
with open(output_path, 'w', newline='') as datafile:
    csvwriter = csv.writer(datafile, delimiter=',')
    csvwriter.writerow([(f"Beginning Data Retrieval")])
    csvwriter.writerow([(f"------------------------")])

    for city in cities: #looping for data extraction, printing and writing
        response = requests.get(query_url + city).json()
        if response['cod'] == 200: #extraction validator. cod = 200 ensures we only excract successful api calls
            cy.append(city) #appending data on lists 
            lat.append(response['coord']['lat'])
            long.append(response['coord']['lon'])
            #res.append(response['cod'])
            #q.append(query_url + city)
            cloud.append(response['clouds']['all'])
            co.append(response['sys']['country'])
            date1.append(response['dt'])
            hum.append(response['main']['humidity'])
            xtemp.append(response['main']['temp_max'])
            ws.append(response['wind']['speed'])
            
            c2 = city.replace(" ","%20") #this will ensure URL's are fully clickable
            
            print(f"Procesing record {i} | {city}.") #printing progress
            print(query_url + c2)
          
            csvwriter.writerow([(f"Procesing record {i} | {city}.")]) #writing 
            csvwriter.writerow([(query_url + c2)])
            
            i = i + 1 #counter to ensure printing corresponds to actual item being process
            
    csvwriter.writerow([(f"------------------------")])
    csvwriter.writerow([(f"Data Retrieval Complete")])
    csvwriter.writerow([(f"------------------------")])
# Out:
# Procesing record 1 | cherskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cherskiy
# Procesing record 2 | bereda.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bereda
# Procesing record 3 | yellowknife.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yellowknife
# Procesing record 4 | touros.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=touros
# Procesing record 5 | avarua.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=avarua
# Procesing record 6 | kruisfontein.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kruisfontein
# Procesing record 7 | mazagao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mazagao
# Procesing record 8 | hithadhoo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hithadhoo
# Procesing record 9 | berlevag.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=berlevag
# Procesing record 10 | fort nelson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fort%20nelson
# Procesing record 11 | pokhara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pokhara
# Procesing record 12 | kavaratti.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kavaratti
# Procesing record 13 | zary.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zary
# Procesing record 14 | puerto ayora.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=puerto%20ayora
# Procesing record 15 | ponta do sol.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ponta%20do%20sol
# Procesing record 16 | busselton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=busselton
# Procesing record 17 | arraial do cabo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=arraial%20do%20cabo
# Procesing record 18 | punta arenas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=punta%20arenas
# Procesing record 19 | jamestown.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jamestown
# Procesing record 20 | cayenne.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cayenne
# Procesing record 21 | hobart.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hobart
# Procesing record 22 | lompoc.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lompoc
# Procesing record 23 | bredasdorp.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bredasdorp
# Procesing record 24 | caraballeda.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=caraballeda
# Procesing record 25 | lata.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lata
# Procesing record 26 | pevek.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pevek
# Procesing record 27 | alta floresta.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alta%20floresta
# Procesing record 28 | atuona.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=atuona
# Procesing record 29 | victoria.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=victoria
# Procesing record 30 | port hardy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20hardy
# Procesing record 31 | cape town.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cape%20town
# Procesing record 32 | itarema.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=itarema
# Procesing record 33 | georgetown.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=georgetown
# Procesing record 34 | norman wells.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=norman%20wells
# Procesing record 35 | rikitea.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rikitea
# Procesing record 36 | esperance.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=esperance
# Procesing record 37 | vardo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vardo
# Procesing record 38 | sitka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sitka
# Procesing record 39 | black diamond.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=black%20diamond
# Procesing record 40 | barrow.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=barrow
# Procesing record 41 | bandarbeyla.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bandarbeyla
# Procesing record 42 | rapar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rapar
# Procesing record 43 | union city.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=union%20city
# Procesing record 44 | huilong.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=huilong
# Procesing record 45 | kuruman.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kuruman
# Procesing record 46 | chokurdakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chokurdakh
# Procesing record 47 | miguel hidalgo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=miguel%20hidalgo
# Procesing record 48 | qaanaaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=qaanaaq
# Procesing record 49 | beruwala.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=beruwala
# Procesing record 50 | bluff.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bluff
# Procesing record 51 | nelson bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nelson%20bay
# Procesing record 52 | kodiak.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kodiak
# Procesing record 53 | torbay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=torbay
# Procesing record 54 | ribeira grande.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ribeira%20grande
# Procesing record 55 | buraydah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=buraydah
# Procesing record 56 | nanortalik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nanortalik
# Procesing record 57 | albany.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=albany
# Procesing record 58 | mar del plata.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mar%20del%20plata
# Procesing record 59 | sabang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sabang
# Procesing record 60 | cienfuegos.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cienfuegos
# Procesing record 61 | trairi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=trairi
# Procesing record 62 | zhicheng.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zhicheng
# Procesing record 63 | ushuaia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ushuaia
# Procesing record 64 | alofi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alofi
# Procesing record 65 | goderich.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=goderich
# Procesing record 66 | estrela.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=estrela
# Procesing record 67 | tuatapere.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tuatapere
# Procesing record 68 | collie.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=collie
# Procesing record 69 | lerwick.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lerwick
# Procesing record 70 | mataura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mataura
# Procesing record 71 | chittur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chittur
# Procesing record 72 | dothan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dothan
# Procesing record 73 | upernavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=upernavik
# Procesing record 74 | gayny.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gayny
# Procesing record 75 | vaini.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vaini
# Procesing record 76 | gold coast.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gold%20coast
# Procesing record 77 | katsuura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=katsuura
# Procesing record 78 | rosarito.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rosarito
# Procesing record 79 | mahebourg.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mahebourg
# Procesing record 80 | udachnyy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=udachnyy
# Procesing record 81 | tiksi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tiksi
# Procesing record 82 | gravdal.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gravdal
# Procesing record 83 | teya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=teya
# Procesing record 84 | kapaa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kapaa
# Procesing record 85 | antofagasta.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=antofagasta
# Procesing record 86 | bontang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bontang
# Procesing record 87 | ko samui.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ko%20samui
# Procesing record 88 | catuday.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=catuday
# Procesing record 89 | jalu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jalu
# Procesing record 90 | kavieng.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kavieng
# Procesing record 91 | taoudenni.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=taoudenni
# Procesing record 92 | gao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gao
# Procesing record 93 | bowen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bowen
# Procesing record 94 | kathu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kathu
# Procesing record 95 | maniitsoq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=maniitsoq
# Procesing record 96 | naze.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=naze
# Procesing record 97 | faanui.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=faanui
# Procesing record 98 | westport.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=westport
# Procesing record 99 | vestmannaeyjar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vestmannaeyjar
# Procesing record 100 | jinchang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jinchang
# Procesing record 101 | sarai alamgir.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sarai%20alamgir
# Procesing record 102 | lebu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lebu
# Procesing record 103 | tallahassee.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tallahassee
# Procesing record 104 | saskylakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saskylakh
# Procesing record 105 | kandiari.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kandiari
# Procesing record 106 | dunedin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dunedin
# Procesing record 107 | mount gambier.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mount%20gambier
# Procesing record 108 | auki.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=auki
# Procesing record 109 | huangpu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=huangpu
# Procesing record 110 | raudeberg.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=raudeberg
# Procesing record 111 | lavrentiya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lavrentiya
# Procesing record 112 | leshukonskoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=leshukonskoye
# Procesing record 113 | vila velha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vila%20velha
# Procesing record 114 | ilulissat.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ilulissat
# Procesing record 115 | benito juarez.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=benito%20juarez
# Procesing record 116 | molo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=molo
# Procesing record 117 | kenai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kenai
# Procesing record 118 | mirnyy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mirnyy
# Procesing record 119 | russellville.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=russellville
# Procesing record 120 | punto fijo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=punto%20fijo
# Procesing record 121 | lasa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lasa
# Procesing record 122 | labytnangi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=labytnangi
# Procesing record 123 | dikson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dikson
# Procesing record 124 | bacolod.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bacolod
# Procesing record 125 | dingle.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dingle
# Procesing record 126 | norrtalje.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=norrtalje
# Procesing record 127 | ivdel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ivdel
# Procesing record 128 | hannoversch munden.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hannoversch%20munden
# Procesing record 129 | dongsheng.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dongsheng
# Procesing record 130 | iwanai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=iwanai
# Procesing record 131 | laguna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=laguna
# Procesing record 132 | berdigestyakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=berdigestyakh
# Procesing record 133 | port elizabeth.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20elizabeth
# Procesing record 134 | port alfred.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20alfred
# Procesing record 135 | sumenep.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sumenep
# Procesing record 136 | mizan teferi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mizan%20teferi
# Procesing record 137 | chauk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chauk
# Procesing record 138 | mao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mao
# Procesing record 139 | voh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=voh
# Procesing record 140 | staroutkinsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=staroutkinsk
# Procesing record 141 | agaro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=agaro
# Procesing record 142 | kahului.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kahului
# Procesing record 143 | tchollire.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tchollire
# Procesing record 144 | hermanus.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hermanus
# Procesing record 145 | aquiraz.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aquiraz
# Procesing record 146 | khatanga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=khatanga
# Procesing record 147 | saint anthony.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint%20anthony
# Procesing record 148 | sampit.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sampit
# Procesing record 149 | hilo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hilo
# Procesing record 150 | husavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=husavik
# Procesing record 151 | pacific grove.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pacific%20grove
# Procesing record 152 | belyy yar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=belyy%20yar
# Procesing record 153 | tuktoyaktuk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tuktoyaktuk
# Procesing record 154 | ancud.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ancud
# Procesing record 155 | navirai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=navirai
# Procesing record 156 | tiko.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tiko
# Procesing record 157 | inta.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=inta
# Procesing record 158 | hirara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hirara
# Procesing record 159 | dunmore town.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dunmore%20town
# Procesing record 160 | bethel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bethel
# Procesing record 161 | indramayu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=indramayu
# Procesing record 162 | lingao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lingao
# Procesing record 163 | kaitangata.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaitangata
# Procesing record 164 | souillac.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=souillac
# Procesing record 165 | leh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=leh
# Procesing record 166 | coquimbo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=coquimbo
# Procesing record 167 | sinnamary.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sinnamary
# Procesing record 168 | ilovlya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ilovlya
# Procesing record 169 | tasiilaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tasiilaq
# Procesing record 170 | salalah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=salalah
# Procesing record 171 | airai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=airai
# Procesing record 172 | luderitz.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=luderitz
# Procesing record 173 | acapulco.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=acapulco
# Procesing record 174 | hasaki.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hasaki
# Procesing record 175 | pangnirtung.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pangnirtung
# Procesing record 176 | takoradi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=takoradi
# Procesing record 177 | anzio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=anzio
# Procesing record 178 | sorong.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sorong
# Procesing record 179 | butaritari.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=butaritari
# Procesing record 180 | moron.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=moron
# Procesing record 181 | isangel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=isangel
# Procesing record 182 | boyolangu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=boyolangu
# Procesing record 183 | wagga wagga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wagga%20wagga
# Procesing record 184 | katherine.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=katherine
# Procesing record 185 | bilibino.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bilibino
# Procesing record 186 | toktogul.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=toktogul
# Procesing record 187 | taywarah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=taywarah
# Procesing record 188 | bonavista.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bonavista
# Procesing record 189 | karratha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=karratha
# Procesing record 190 | samarai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=samarai
# Procesing record 191 | nome.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nome
# Procesing record 192 | haines junction.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=haines%20junction
# Procesing record 193 | hamilton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hamilton
# Procesing record 194 | fairbanks.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fairbanks
# Procesing record 195 | adrar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=adrar
# Procesing record 196 | dzhalil.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dzhalil
# Procesing record 197 | lakes entrance.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lakes%20entrance
# Procesing record 198 | camacha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=camacha
# Procesing record 199 | avera.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=avera
# Procesing record 200 | nikolskoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nikolskoye
# Procesing record 201 | waslala.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=waslala
# Procesing record 202 | castro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=castro
# Procesing record 203 | bam.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bam
# Procesing record 204 | thompson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=thompson
# Procesing record 205 | east london.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=east%20london
# Procesing record 206 | atar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=atar
# Procesing record 207 | leua.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=leua
# Procesing record 208 | nikko.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nikko
# Procesing record 209 | mayor pablo lagerenza.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mayor%20pablo%20lagerenza
# Procesing record 210 | ahipara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ahipara
# Procesing record 211 | harper.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=harper
# Procesing record 212 | lobito.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lobito
# Procesing record 213 | tynda.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tynda
# Procesing record 214 | aykhal.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aykhal
# Procesing record 215 | new norfolk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=new%20norfolk
# Procesing record 216 | port-gentil.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port-gentil
# Procesing record 217 | sussex.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sussex
# Procesing record 218 | chuy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chuy
# Procesing record 219 | grindavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=grindavik
# Procesing record 220 | forestville.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=forestville
# Procesing record 221 | la ronge.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=la%20ronge
# Procesing record 222 | meulaboh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=meulaboh
# Procesing record 223 | northam.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=northam
# Procesing record 224 | praia da vitoria.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=praia%20da%20vitoria
# Procesing record 225 | half moon bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=half%20moon%20bay
# Procesing record 226 | gamba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gamba
# Procesing record 227 | mossendjo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mossendjo
# Procesing record 228 | eenhana.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=eenhana
# Procesing record 229 | batemans bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=batemans%20bay
# Procesing record 230 | pointe michel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pointe%20michel
# Procesing record 231 | bartica.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bartica
# Procesing record 232 | jardim.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jardim
# Procesing record 233 | moncton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=moncton
# Procesing record 234 | san patricio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20patricio
# Procesing record 235 | vostok.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vostok
# Procesing record 236 | sechura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sechura
# Procesing record 237 | rio gallegos.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rio%20gallegos
# Procesing record 238 | kaohsiung.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaohsiung
# Procesing record 239 | noumea.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=noumea
# Procesing record 240 | ngunguru.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ngunguru
# Procesing record 241 | kollam.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kollam
# Procesing record 242 | dolores.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dolores
# Procesing record 243 | lumeje.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lumeje
# Procesing record 244 | port lincoln.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20lincoln
# Procesing record 245 | shetpe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=shetpe
# Procesing record 246 | provideniya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=provideniya
# Procesing record 247 | filingue.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=filingue
# Procesing record 248 | ustka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ustka
# Procesing record 249 | boa vista.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=boa%20vista
# Procesing record 250 | talnakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=talnakh
# Procesing record 251 | visby.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=visby
# Procesing record 252 | fortuna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fortuna
# Procesing record 253 | constitucion.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=constitucion
# Procesing record 254 | mantua.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mantua
# Procesing record 255 | sexsmith.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sexsmith
# Procesing record 256 | mount isa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mount%20isa
# Procesing record 257 | abu dhabi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=abu%20dhabi
# Procesing record 258 | alberton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alberton
# Procesing record 259 | baykit.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=baykit
# Procesing record 260 | cidreira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cidreira
# Procesing record 261 | champerico.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=champerico
# Procesing record 262 | jacarezinho.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jacarezinho
# Procesing record 263 | walvis bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=walvis%20bay
# Procesing record 264 | cocorit.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cocorit
# Procesing record 265 | saint-augustin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint-augustin
# Procesing record 266 | narsaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=narsaq
# Procesing record 267 | dali.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dali
# Procesing record 268 | pathein.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pathein
# Procesing record 269 | saint george.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint%20george
# Procesing record 270 | discovery bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=discovery%20bay
# Procesing record 271 | verkhoyansk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=verkhoyansk
# Procesing record 272 | dezful.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dezful
# Procesing record 273 | villanueva de la serena.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=villanueva%20de%20la%20serena
# Procesing record 274 | sola.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sola
# Procesing record 275 | stokmarknes.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=stokmarknes
# Procesing record 276 | mumford.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mumford
# Procesing record 277 | nisia floresta.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nisia%20floresta
# Procesing record 278 | dwarka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dwarka
# Procesing record 279 | narrabri.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=narrabri
# Procesing record 280 | kerema.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kerema
# Procesing record 281 | saint-philippe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint-philippe
# Procesing record 282 | srandakan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=srandakan
# Procesing record 283 | xining.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=xining
# Procesing record 284 | villa corona.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=villa%20corona
# Procesing record 285 | hongjiang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hongjiang
# Procesing record 286 | tautira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tautira
# Procesing record 287 | creel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=creel
# Procesing record 288 | tumarbong.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tumarbong
# Procesing record 289 | majene.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=majene
# Procesing record 290 | luganville.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=luganville
# Procesing record 291 | lakselv.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lakselv
# Procesing record 292 | garowe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=garowe
# Procesing record 293 | necochea.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=necochea
# Procesing record 294 | oudtshoorn.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oudtshoorn
# Procesing record 295 | deputatskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=deputatskiy
# Procesing record 296 | yarmouth.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yarmouth
# Procesing record 297 | severo-kurilsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=severo-kurilsk
# Procesing record 298 | teacapan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=teacapan
# Procesing record 299 | porbandar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=porbandar
# Procesing record 300 | fomboni.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fomboni
# Procesing record 301 | codrington.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=codrington
# Procesing record 302 | ucluelet.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ucluelet
# Procesing record 303 | roseto degli abruzzi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=roseto%20degli%20abruzzi
# Procesing record 304 | kloulklubed.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kloulklubed
# Procesing record 305 | ambilobe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ambilobe
# Procesing record 306 | jamame.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jamame
# Procesing record 307 | shepsi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=shepsi
# Procesing record 308 | beyneu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=beyneu
# Procesing record 309 | klaksvik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=klaksvik
# Procesing record 310 | fayaoue.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fayaoue
# Procesing record 311 | adeje.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=adeje
# Procesing record 312 | aberdeen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aberdeen
# Procesing record 313 | kabanjahe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kabanjahe
# Procesing record 314 | bambous virieux.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bambous%20virieux
# Procesing record 315 | kaniama.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaniama
# Procesing record 316 | blackwater.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=blackwater
# Procesing record 317 | kuito.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kuito
# Procesing record 318 | washington.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=washington
# Procesing record 319 | biograd na moru.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=biograd%20na%20moru
# Procesing record 320 | gazli.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gazli
# Procesing record 321 | cardston.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cardston
# Procesing record 322 | paamiut.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=paamiut
# Procesing record 323 | sargatskoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sargatskoye
# Procesing record 324 | asyut.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=asyut
# Procesing record 325 | wschowa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wschowa
# Procesing record 326 | port moresby.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20moresby
# Procesing record 327 | coihueco.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=coihueco
# Procesing record 328 | grand-lahou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=grand-lahou
# Procesing record 329 | itapetinga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=itapetinga
# Procesing record 330 | bonthe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bonthe
# Procesing record 331 | mareeba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mareeba
# Procesing record 332 | tazovskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tazovskiy
# Procesing record 333 | elizabeth city.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=elizabeth%20city
# Procesing record 334 | hambantota.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hambantota
# Procesing record 335 | pochutla.
# ...
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hobyo
# Procesing record 442 | cukai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cukai
# Procesing record 443 | gallup.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gallup
# Procesing record 444 | sumbe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sumbe
# Procesing record 445 | romny.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=romny
# Procesing record 446 | luang prabang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=luang%20prabang
# Procesing record 447 | kirensk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kirensk
# Procesing record 448 | basco.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=basco
# Procesing record 449 | wajid.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wajid
# Procesing record 450 | bathsheba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bathsheba
# Procesing record 451 | nyuksenitsa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nyuksenitsa
# Procesing record 452 | praia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=praia
# Procesing record 453 | alcantara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alcantara
# Procesing record 454 | san rafael del sur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20rafael%20del%20sur
# Procesing record 455 | amzya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=amzya
# Procesing record 456 | college.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=college
# Procesing record 457 | lagoa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lagoa
# Procesing record 458 | axim.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=axim
# Procesing record 459 | antalaha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=antalaha
# Procesing record 460 | lima.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lima
# Procesing record 461 | zabid.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zabid
# Procesing record 462 | celestun.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=celestun
# Procesing record 463 | tottori.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tottori
# Procesing record 464 | oregon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oregon
# Procesing record 465 | upington.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=upington
# Procesing record 466 | palana.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=palana
# Procesing record 467 | igarka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=igarka
# Procesing record 468 | khor.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=khor
# Procesing record 469 | log.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=log
# Procesing record 470 | san clemente.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20clemente
# Procesing record 471 | huron.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=huron
# Procesing record 472 | chumikan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chumikan
# Procesing record 473 | surt.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=surt
# Procesing record 474 | richards bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=richards%20bay
# Procesing record 475 | dubbo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dubbo
# Procesing record 476 | payo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=payo
# Procesing record 477 | kieta.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kieta
# Procesing record 478 | doha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=doha
# Procesing record 479 | salina cruz.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=salina%20cruz
# Procesing record 480 | ust-karsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ust-karsk
# Procesing record 481 | sao filipe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sao%20filipe
# Procesing record 482 | beringovskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=beringovskiy
# Procesing record 483 | santa lucia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=santa%20lucia
# Procesing record 484 | kampong chhnang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kampong%20chhnang
# Procesing record 485 | cacapava do sul.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cacapava%20do%20sul
# Procesing record 486 | nicoya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nicoya
# Procesing record 487 | namibe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=namibe
# Procesing record 488 | alabaster.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alabaster
# Procesing record 489 | poum.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=poum
# Procesing record 490 | gimbi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gimbi
# Procesing record 491 | srednekolymsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=srednekolymsk
# Procesing record 492 | san cristobal.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20cristobal
# Procesing record 493 | kupang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kupang
# Procesing record 494 | ossora.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ossora
# Procesing record 495 | los llanos de aridane.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=los%20llanos%20de%20aridane
# Procesing record 496 | tiwi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tiwi
# Procesing record 497 | susangerd.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=susangerd
# Procesing record 498 | kaeo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaeo
# Procesing record 499 | khuzdar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=khuzdar
# Procesing record 500 | sao gabriel da cachoeira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sao%20gabriel%20da%20cachoeira
# Procesing record 501 | yuzhno-kurilsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yuzhno-kurilsk
# Procesing record 502 | clyde river.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=clyde%20river
# Procesing record 503 | bloemfontein.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bloemfontein
# Procesing record 504 | owando.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=owando
# Procesing record 505 | ridgecrest.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ridgecrest
# Procesing record 506 | valley city.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=valley%20city
# Procesing record 507 | sao joao da barra.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sao%20joao%20da%20barra
# Procesing record 508 | henties bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=henties%20bay
# Procesing record 509 | riyadh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=riyadh
# Procesing record 510 | farafangana.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=farafangana
# Procesing record 511 | jinsha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jinsha
# Procesing record 512 | nouadhibou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nouadhibou
# Procesing record 513 | sawakin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sawakin
# Procesing record 514 | jiblah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jiblah
# Procesing record 515 | ayna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ayna
# Procesing record 516 | labuhan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=labuhan
# Procesing record 517 | eravur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=eravur
# Procesing record 518 | aguimes.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aguimes
# Procesing record 519 | turochak.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=turochak
# Procesing record 520 | najran.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=najran
# Procesing record 521 | nortelandia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nortelandia
# Procesing record 522 | dahanu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dahanu
# Procesing record 523 | alyangula.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alyangula
# Procesing record 524 | rudnyy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rudnyy
# Procesing record 525 | umm kaddadah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=umm%20kaddadah
# Procesing record 526 | san javier.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20javier
# Procesing record 527 | hovd.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hovd
# Procesing record 528 | megion.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=megion
# Procesing record 529 | pareora.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pareora
# Procesing record 530 | ust-omchug.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ust-omchug
# Procesing record 531 | rodrigues alves.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rodrigues%20alves
# Procesing record 532 | north bend.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=north%20bend
# Procesing record 533 | evensk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=evensk
# Procesing record 534 | manzil kamil.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=manzil%20kamil
# Procesing record 535 | galle.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=galle
# Procesing record 536 | ardalstangen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ardalstangen
# Procesing record 537 | hvide sande.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hvide%20sande
# Procesing record 538 | denpasar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=denpasar
# Procesing record 539 | havelock.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=havelock
# Procesing record 540 | oistins.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oistins
# Procesing record 541 | soe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=soe
# Procesing record 542 | lacarak.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lacarak
# Procesing record 543 | bilma.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bilma
# Procesing record 544 | rocky mountain house.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rocky%20mountain%20house
# Procesing record 545 | aksu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aksu
# Procesing record 546 | sawtell.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sawtell
# Procesing record 547 | pangody.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pangody
# Procesing record 548 | west wendover.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=west%20wendover
# Procesing record 549 | victoria point.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=victoria%20point
# Procesing record 550 | roald.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=roald
# Procesing record 551 | bressuire.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bressuire

# %%
#adding lists to dataframes

d['City'] = cy
d['Cloudiness'] = cloud
d['Country'] = co
d['Date'] = date1
d['Humidity'] = hum
d['Lat'] = lat
d['Lng'] = long
d['Max Temp'] = xtemp
d['Wind Speed'] = ws

#writing a file with resulting dataframe 
d.to_csv(f"output_data_file_{t}.csv", index=False)

# %%
d #resuting dataframe
# Out:
#                      City  Cloudiness Country        Date  Humidity    Lat  \
# 0                cherskiy          32      RU  1550974514        79  68.75
# 1                  bereda           0      ES  1550971800        81  43.27
# 2             yellowknife          20      CA  1550970000        68  62.45
# 3                  touros          12      BR  1550974393        97  -5.20
# 4                  avarua          92      CK  1550971800        66 -21.21
# 5            kruisfontein          68      ZA  1550974441        86 -34.00
# 6                 mazagao          75      BR  1550970000       100  -0.12
# 7               hithadhoo          56      MV  1550974303       100  -0.60
# 8                berlevag          76      NO  1550974516        96  70.86
# 9             fort nelson          20      CA  1550970000        65  58.81
# 10                pokhara          80      NP  1550974516        55  28.21
# 11              kavaratti           0      IN  1550974516       100  10.57
# 12                   zary          44      PL  1550974517        67  51.64
# 13           puerto ayora          56      EC  1550974517       100  -0.74
# 14           ponta do sol           8      BR  1550974517        84 -20.63
# 15              busselton           0      AU  1550974385        93 -33.64
# 16        arraial do cabo          20      BR  1550974518        88 -22.97
# 17           punta arenas          75      CL  1550970000        45 -53.16
# 18              jamestown           0      AU  1550974519        26 -33.21
# 19                cayenne          76      GF  1550971800        74   4.94
# 20                 hobart           0      AU  1550971800        46 -42.88
# 21                 lompoc           1      US  1550973360        71  34.64
# 22             bredasdorp          80      ZA  1550973600        77 -34.53
# 23            caraballeda          20      VE  1550970000        73  10.61
# 24                   lata          76      IN  1550974520        81  30.78
# 25                  pevek          88      RU  1550974520       100  69.70
# 26          alta floresta          88      BR  1550974462        91  -9.87
# 27                 atuona           0      PF  1550974520        99  -9.80
# 28               victoria          75      BN  1550971800        88   5.28
# 29             port hardy          75      CA  1550972760        86  50.70
# ..                    ...         ...     ...         ...       ...    ...
# 521                dahanu           8      IN  1550974647        95  19.97
# 522             alyangula          75      AU  1550970000        62 -13.85
# 523                rudnyy          20      KZ  1550971800        84  52.96
# 524          umm kaddadah          24      SD  1550974648        35  13.60
# 525            san javier           0      ES  1550971800        70  37.81
# 526                  hovd          90      NO  1550973000       100  63.83
# 527                megion          90      RU  1550971800       100  61.04
# 528               pareora          92      NZ  1550974649       100 -44.49
# 529            ust-omchug           0      RU  1550974650        58  61.13
# 530       rodrigues alves          20      BR  1550970000        88  -7.74
# 531            north bend          90      US  1550969760        93  43.41
# 532                evensk          64      RU  1550974650       100  61.92
# 533          manzil kamil           0      TN  1550971800        66  35.62
# 534                 galle           1      US  1550973360        30  29.74
# 535          ardalstangen          68      NO  1550974651        93  61.24
# 536           hvide sande           0      DK  1550973000        95  56.01
# 537              denpasar          40      ID  1550971800        79  -8.65
# 538              havelock          90      US  1550972940        93  34.88
# 539               oistins          75      BB  1550970000        74  13.07
# 540                   soe          36      EE  1550969400       100  57.91
# 541               lacarak           0      RS  1550971800        85  45.00
# 542                 bilma           0      NE  1550974652        32  18.69
# 543  rocky mountain house          68      CA  1550974653        63  52.38
# 544                  aksu           0      KZ  1550971800        84  52.04
# 545               sawtell          75      AU  1550973420        61 -30.38
# 546               pangody          68      RU  1550974653        59  65.85
# 547         west wendover          20      US  1550969760        47  40.74
# 548        victoria point          75      AU  1550972040        44 -27.58
# 549                 roald          92      NO  1550973000        81  62.58
# 550             bressuire           0      FR  1550971800        86  46.84
#
#         Lng  Max Temp  Wind Speed
# 0    161.30    -28.13        2.51
# 1     -7.54     10.00        2.60
# 2   -114.38    -26.00        2.60
# 3    -35.46     25.38        2.11
# 4   -159.78     29.00        6.70
# 5     24.73     17.95        2.51
# 6    -51.29     25.00        3.60
# 7     73.08     28.35        3.81
# 8     29.09      2.63        4.26
# 9   -122.69    -13.00        1.50
# 10    83.99     11.80        1.41
# 11    72.64     27.70        2.71
# 12    15.14     -4.50        1.56
# 13   -90.35     25.43        1.96
# 14   -46.00     19.73        1.21
# 15   115.35     21.80        5.26
# 16   -42.02     26.30        5.71
# 17   -70.91      6.00        5.70
# 18   138.60     31.45        4.51
# 19   -52.33     26.00        3.10
# 20   147.33     21.00        1.50
# 21  -120.46     13.00        2.10
# 22    20.04     20.00        0.50
# 23   -66.85     25.00        0.50
# 24    78.62      1.88        0.76
# 25   170.27    -23.28        6.56
# 26   -56.08     25.18        0.46
# 27  -139.03     27.73        6.46
# 28   115.24     27.00        1.50
# 29  -127.42      4.00        3.10
# ..      ...       ...         ...
# 521   72.73     23.48        4.31
# 522  136.42     32.00        3.60
# 523   63.12    -15.00        7.00
# 524   26.69     13.98        1.41
# 525   -0.83     12.00        1.50
# 526   10.70      6.00        0.50
# 527   76.11     -7.00        3.00
# 528  171.21      8.38        5.81
# 529  149.63    -25.85        1.51
# 530  -72.65     26.00        1.41
# 531 -124.22      9.00        6.20
# 532  159.24    -17.45        1.86
# 533   10.67     10.00       13.90
# 534  -97.91     18.00        2.60
# 535    7.70     -0.25        1.41
# 536    8.13      2.00        1.50
# 537  115.22     29.00        2.60
# 538  -76.90     13.00        3.60
# 539  -59.53     26.00        9.30
# 540   26.05      1.00        6.70
# 541   19.56     -6.00        2.46
# 542   12.92     12.83        5.01
# 543 -114.92    -15.68        2.01
# 544   76.93    -19.00        3.00
# 545  153.10     27.00       10.80
# 546   74.49    -24.90        1.51
# 547 -114.07      2.00        0.76
# 548  153.30     27.00        6.70
# 549    6.12     10.00        7.70
# 550   -0.49      6.00        3.60
#
# [551 rows x 9 columns]

# %%
d.describe() #I usually use this to get a sense of data
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  551.000000  5.510000e+02  551.000000  551.000000  551.000000
# mean    39.560799  1.550973e+09   75.637024   19.476425   17.410599
# std     35.976753  1.883692e+03   20.404251   32.289826   89.691605
# min      0.000000  1.550969e+09    5.000000  -54.810000 -173.230000
# 25%      0.000000  1.550972e+09   63.000000   -4.615000  -61.415000
# 50%     32.000000  1.550974e+09   79.000000   22.080000   16.050000
# 75%     75.000000  1.550975e+09   93.000000   45.440000   96.895000
# max    100.000000  1.550975e+09  100.000000   77.480000  179.320000
#
#          Max Temp  Wind Speed
# count  551.000000  551.000000
# mean    11.116697    3.776425
# std     15.850485    2.885093
# min    -35.650000    0.160000
# 25%      1.440000    1.510000
# 50%     15.000000    3.000000
# 75%     24.775000    5.100000
# max     38.880000   19.000000

# %%
# the subsquent scatter plot charts follow similar steps

fig, ax = plt.subplots()

# assigning data to axis

x_axis = d['Lat']
y_axis = d['Max Temp']

#setting up graph and properties
plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

# title includes today's date
plt.title(f"City Latitude vs. Max Temperature ({t})")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save Figure - file includes today's date
plt.savefig(f"City Latitude vs. Max Temperature_{t}.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Humidity']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title(f"City Latitude vs Humidity ({t})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save Figure

plt.savefig(f"City Latitude vs. Humidity_{t}.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Cloudiness']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title(f"City Latitude vs Cloudiness ({t})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save Figure

plt.savefig(f"City Latitude vs. Cloudiness_{t}.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Wind Speed']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title(f"City Latitude vs Wind Speed ({t})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (Kph)")

# Save Figure

plt.savefig(f"City Latitude vs. Wind Speed_{t}.png")

plt.show()
