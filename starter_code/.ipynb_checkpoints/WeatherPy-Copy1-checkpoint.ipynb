# %% [markdown]
# # WeatherPy - Leo Santos - Analysis
# ----
#
# ### Analysis
# #1 In terms of latitude and max temperature, as of Feb 23, 2019, data shows warmer temperatures mostly leaning below 20 degrees north latitude (tropic of cancer) and mainly below the equator (southern hemisphere). These observations follow expected behavior: summer in the south and winter in the north at the moment.
#
# #2 City latitude does not seem to explain humidity; there not seem to be a strong correlation between these two variables.  In fact, I confirmed a very low R2 via excel.  Interesting fact: as I run the model several times, there were a few times where one or two outliers at >100% appeared on the plot.  It will have hard to live in "Paita, Peru" where there is a 290% humidity!
#
# #3 Latitude and cloudiness don't show a strong correlation.  there are a couple of horizontal lines that could somehow group many cloudiness levels; however, it will give no signs of correlation.
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


res = []
q = []
cy = []
cloud = []
co = []
date1 = []
hum = []
lat = []
long = []
xtemp = []
ws =[]
d = pd.DataFrame()


# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
# set up lists to hold reponse inf

# %%
# Loop through the list of cities and perform a request for data on each
i = 1
output_path = ("data_retrieval.txt")
with open(output_path, 'w', newline='') as datafile:
    csvwriter = csv.writer(datafile, delimiter=',')
    csvwriter.writerow([(f"Beginning Data Retrieval")])
    csvwriter.writerow([(f"------------------------")])

    for city in cities:
        response = requests.get(query_url + city).json()
        if response['cod'] == 200:
            cy.append(city)
            lat.append(response['coord']['lat'])
            long.append(response['coord']['lon'])
            #res.append(response['cod'])
            #q.append(query_url + city)
            cloud.append(response['clouds']['all'])
            co.append(response['sys']['country'])
            date1.append(response['dt'])
            hum.append(response['main']['humidity'])
            xtemp.append(response['main']['temp_max'])
            ws.append(response['wind']['speed'])
            
            c2 = city.replace(" ","%20")
            
            print(f"Procesing record {i} | {city}.")
            print(query_url + c2)
          
            csvwriter.writerow([(f"Procesing record {i} | {city}.")])
            csvwriter.writerow([(query_url + c2)])
            
            i = i + 1
            
    csvwriter.writerow([(f"------------------------")])
    csvwriter.writerow([(f"Data Retrieval Complete")])
    csvwriter.writerow([(f"------------------------")])
# Out:
# Procesing record 1 | albany.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=albany
# Procesing record 2 | new norfolk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=new%20norfolk
# Procesing record 3 | timmins.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=timmins
# Procesing record 4 | kaitangata.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaitangata
# Procesing record 5 | hilo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hilo
# Procesing record 6 | salinas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=salinas
# Procesing record 7 | kruisfontein.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kruisfontein
# Procesing record 8 | corabia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=corabia
# Procesing record 9 | ribeira grande.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ribeira%20grande
# Procesing record 10 | khatanga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=khatanga
# Procesing record 11 | coquimbo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=coquimbo
# Procesing record 12 | soe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=soe
# Procesing record 13 | butaritari.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=butaritari
# Procesing record 14 | bethel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bethel
# Procesing record 15 | georgetown.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=georgetown
# Procesing record 16 | tarakan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tarakan
# Procesing record 17 | bontang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bontang
# Procesing record 18 | busselton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=busselton
# Procesing record 19 | fukue.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fukue
# Procesing record 20 | eregli.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=eregli
# Procesing record 21 | newport.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=newport
# Procesing record 22 | mao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mao
# Procesing record 23 | longyearbyen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=longyearbyen
# Procesing record 24 | zwedru.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zwedru
# Procesing record 25 | barrow.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=barrow
# Procesing record 26 | inirida.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=inirida
# Procesing record 27 | bluff.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bluff
# Procesing record 28 | atuona.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=atuona
# Procesing record 29 | hobart.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hobart
# Procesing record 30 | guerrero negro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=guerrero%20negro
# Procesing record 31 | yen bai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yen%20bai
# Procesing record 32 | zarechnyy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zarechnyy
# Procesing record 33 | zhumadian.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zhumadian
# Procesing record 34 | viedma.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=viedma
# Procesing record 35 | rikitea.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rikitea
# Procesing record 36 | ushuaia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ushuaia
# Procesing record 37 | westport.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=westport
# Procesing record 38 | port said.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20said
# Procesing record 39 | tiksi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tiksi
# Procesing record 40 | mataura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mataura
# Procesing record 41 | taunggyi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=taunggyi
# Procesing record 42 | batemans bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=batemans%20bay
# Procesing record 43 | bambous virieux.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bambous%20virieux
# Procesing record 44 | knysna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=knysna
# Procesing record 45 | castro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=castro
# Procesing record 46 | atambua.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=atambua
# Procesing record 47 | pisco.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pisco
# Procesing record 48 | qaanaaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=qaanaaq
# Procesing record 49 | ploemeur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ploemeur
# Procesing record 50 | sherpur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sherpur
# Procesing record 51 | clyde river.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=clyde%20river
# Procesing record 52 | sao filipe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sao%20filipe
# Procesing record 53 | douentza.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=douentza
# Procesing record 54 | kudahuvadhoo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kudahuvadhoo
# Procesing record 55 | karasburg.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=karasburg
# Procesing record 56 | vaini.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vaini
# Procesing record 57 | cape town.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cape%20town
# Procesing record 58 | moron.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=moron
# Procesing record 59 | east london.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=east%20london
# Procesing record 60 | port hedland.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20hedland
# Procesing record 61 | avarua.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=avarua
# Procesing record 62 | carnarvon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=carnarvon
# Procesing record 63 | cidreira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cidreira
# Procesing record 64 | geraldton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=geraldton
# Procesing record 65 | yellowknife.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yellowknife
# Procesing record 66 | esperance.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=esperance
# Procesing record 67 | marfino.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=marfino
# Procesing record 68 | zabol.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zabol
# Procesing record 69 | hithadhoo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hithadhoo
# Procesing record 70 | satellite beach.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=satellite%20beach
# Procesing record 71 | lazaro cardenas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lazaro%20cardenas
# Procesing record 72 | cherskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cherskiy
# Procesing record 73 | thompson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=thompson
# Procesing record 74 | port macquarie.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20macquarie
# Procesing record 75 | souillac.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=souillac
# Procesing record 76 | biograd na moru.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=biograd%20na%20moru
# Procesing record 77 | tornio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tornio
# Procesing record 78 | hamilton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hamilton
# Procesing record 79 | saldanha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saldanha
# Procesing record 80 | nyurba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nyurba
# Procesing record 81 | podgornoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=podgornoye
# Procesing record 82 | abbeville.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=abbeville
# Procesing record 83 | tinskoy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tinskoy
# Procesing record 84 | hermanus.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hermanus
# Procesing record 85 | saint-philippe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint-philippe
# Procesing record 86 | namibe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=namibe
# Procesing record 87 | seymchan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=seymchan
# Procesing record 88 | terney.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=terney
# Procesing record 89 | huntingdon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=huntingdon
# Procesing record 90 | saskylakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saskylakh
# Procesing record 91 | egvekinot.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=egvekinot
# Procesing record 92 | husavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=husavik
# Procesing record 93 | hambantota.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hambantota
# Procesing record 94 | tigil.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tigil
# Procesing record 95 | ponta do sol.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ponta%20do%20sol
# Procesing record 96 | pevek.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pevek
# Procesing record 97 | kapaa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kapaa
# Procesing record 98 | high level.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=high%20level
# Procesing record 99 | porto walter.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=porto%20walter
# Procesing record 100 | svecha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=svecha
# Procesing record 101 | ilulissat.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ilulissat
# Procesing record 102 | dikson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dikson
# Procesing record 103 | saint george.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint%20george
# Procesing record 104 | saint anthony.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint%20anthony
# Procesing record 105 | haizhou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=haizhou
# Procesing record 106 | bansud.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bansud
# Procesing record 107 | muli.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=muli
# Procesing record 108 | ishigaki.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ishigaki
# Procesing record 109 | yulara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yulara
# Procesing record 110 | chiredzi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chiredzi
# Procesing record 111 | visby.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=visby
# Procesing record 112 | weihe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=weihe
# Procesing record 113 | jishou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jishou
# Procesing record 114 | yagodnoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yagodnoye
# Procesing record 115 | belmonte.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=belmonte
# Procesing record 116 | pleasanton.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pleasanton
# Procesing record 117 | tuktoyaktuk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tuktoyaktuk
# Procesing record 118 | grand-santi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=grand-santi
# Procesing record 119 | berlevag.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=berlevag
# Procesing record 120 | upernavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=upernavik
# Procesing record 121 | lebu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lebu
# Procesing record 122 | great falls.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=great%20falls
# Procesing record 123 | ko samui.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ko%20samui
# Procesing record 124 | maragogi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=maragogi
# Procesing record 125 | port alfred.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20alfred
# Procesing record 126 | leningradskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=leningradskiy
# Procesing record 127 | faya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=faya
# Procesing record 128 | carballo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=carballo
# Procesing record 129 | punta arenas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=punta%20arenas
# Procesing record 130 | tasiilaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tasiilaq
# Procesing record 131 | alice springs.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alice%20springs
# Procesing record 132 | namatanai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=namatanai
# Procesing record 133 | angoche.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=angoche
# Procesing record 134 | harper.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=harper
# Procesing record 135 | mount gambier.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mount%20gambier
# Procesing record 136 | rudnogorsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=rudnogorsk
# Procesing record 137 | victoria.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=victoria
# Procesing record 138 | maceio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=maceio
# Procesing record 139 | mamallapuram.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mamallapuram
# Procesing record 140 | kavieng.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kavieng
# Procesing record 141 | luderitz.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=luderitz
# Procesing record 142 | igarka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=igarka
# Procesing record 143 | wuwei.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wuwei
# Procesing record 144 | merritt.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=merritt
# Procesing record 145 | kulhudhuffushi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kulhudhuffushi
# Procesing record 146 | sterling.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sterling
# Procesing record 147 | yumen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yumen
# Procesing record 148 | nemuro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nemuro
# Procesing record 149 | matamoros.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=matamoros
# Procesing record 150 | mungwi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mungwi
# Procesing record 151 | larap.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=larap
# Procesing record 152 | bedesa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bedesa
# Procesing record 153 | faanui.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=faanui
# Procesing record 154 | nikolskoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nikolskoye
# Procesing record 155 | bakel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bakel
# Procesing record 156 | sur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sur
# Procesing record 157 | jega.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jega
# Procesing record 158 | khandyga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=khandyga
# Procesing record 159 | crotone.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=crotone
# Procesing record 160 | richards bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=richards%20bay
# Procesing record 161 | jamestown.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jamestown
# Procesing record 162 | vung tau.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vung%20tau
# Procesing record 163 | camopi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=camopi
# Procesing record 164 | raudeberg.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=raudeberg
# Procesing record 165 | pichayevo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pichayevo
# Procesing record 166 | vila nova de milfontes.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vila%20nova%20de%20milfontes
# Procesing record 167 | mar del plata.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mar%20del%20plata
# Procesing record 168 | madaba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=madaba
# Procesing record 169 | carupano.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=carupano
# Procesing record 170 | airai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=airai
# Procesing record 171 | vila.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vila
# Procesing record 172 | sibolga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sibolga
# Procesing record 173 | tuscaloosa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tuscaloosa
# Procesing record 174 | puerto ayora.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=puerto%20ayora
# Procesing record 175 | sorong.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sorong
# Procesing record 176 | lufilufi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lufilufi
# Procesing record 177 | mahebourg.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mahebourg
# Procesing record 178 | tilichiki.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tilichiki
# Procesing record 179 | bredasdorp.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bredasdorp
# Procesing record 180 | astana.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=astana
# Procesing record 181 | lompoc.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lompoc
# Procesing record 182 | morris.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=morris
# Procesing record 183 | buala.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=buala
# Procesing record 184 | ahipara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ahipara
# Procesing record 185 | gorgan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gorgan
# Procesing record 186 | yilan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yilan
# Procesing record 187 | temnikov.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=temnikov
# Procesing record 188 | waingapu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=waingapu
# Procesing record 189 | san cristobal.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20cristobal
# Procesing record 190 | northam.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=northam
# Procesing record 191 | shache.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=shache
# Procesing record 192 | hohhot.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hohhot
# Procesing record 193 | margate.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=margate
# Procesing record 194 | ipixuna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ipixuna
# Procesing record 195 | port elizabeth.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20elizabeth
# Procesing record 196 | ostrovnoy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ostrovnoy
# Procesing record 197 | norman wells.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=norman%20wells
# Procesing record 198 | chuy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chuy
# Procesing record 199 | vardo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vardo
# Procesing record 200 | vila velha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vila%20velha
# Procesing record 201 | grindavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=grindavik
# Procesing record 202 | alyangula.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alyangula
# Procesing record 203 | medina.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=medina
# Procesing record 204 | codrington.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=codrington
# Procesing record 205 | tura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tura
# Procesing record 206 | yuyao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yuyao
# Procesing record 207 | betare oya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=betare%20oya
# Procesing record 208 | zhigansk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zhigansk
# Procesing record 209 | kribi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kribi
# Procesing record 210 | fayaoue.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fayaoue
# Procesing record 211 | el alto.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=el%20alto
# Procesing record 212 | henties bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=henties%20bay
# Procesing record 213 | touros.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=touros
# Procesing record 214 | narsaq.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=narsaq
# Procesing record 215 | shakhtinsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=shakhtinsk
# Procesing record 216 | torbay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=torbay
# Procesing record 217 | losone.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=losone
# Procesing record 218 | fortuna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=fortuna
# Procesing record 219 | wanning.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wanning
# Procesing record 220 | hesla.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hesla
# Procesing record 221 | ust-kut.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ust-kut
# Procesing record 222 | mezen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mezen
# Procesing record 223 | los llanos de aridane.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=los%20llanos%20de%20aridane
# Procesing record 224 | okha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=okha
# Procesing record 225 | port lincoln.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20lincoln
# Procesing record 226 | laguna.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=laguna
# Procesing record 227 | hualmay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hualmay
# Procesing record 228 | letlhakane.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=letlhakane
# Procesing record 229 | amapa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=amapa
# Procesing record 230 | teguldet.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=teguldet
# Procesing record 231 | genhe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=genhe
# Procesing record 232 | ziro.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ziro
# Procesing record 233 | dukat.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dukat
# Procesing record 234 | birjand.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=birjand
# Procesing record 235 | kumluca.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kumluca
# Procesing record 236 | hasaki.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hasaki
# Procesing record 237 | itaituba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=itaituba
# Procesing record 238 | beihai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=beihai
# Procesing record 239 | aksarka.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aksarka
# Procesing record 240 | cascais.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cascais
# Procesing record 241 | bukachacha.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bukachacha
# Procesing record 242 | waipawa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=waipawa
# Procesing record 243 | avera.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=avera
# Procesing record 244 | arraial do cabo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=arraial%20do%20cabo
# Procesing record 245 | palu.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=palu
# Procesing record 246 | oshawa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oshawa
# Procesing record 247 | hami.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hami
# Procesing record 248 | nola.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nola
# Procesing record 249 | wajir.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=wajir
# Procesing record 250 | chokurdakh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chokurdakh
# Procesing record 251 | zhuhai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zhuhai
# Procesing record 252 | imuris.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=imuris
# Procesing record 253 | lavrentiya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lavrentiya
# Procesing record 254 | ekuvukeni.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ekuvukeni
# Procesing record 255 | porto murtinho.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=porto%20murtinho
# Procesing record 256 | puerto rico.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=puerto%20rico
# Procesing record 257 | half moon bay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=half%20moon%20bay
# Procesing record 258 | bainbridge.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bainbridge
# Procesing record 259 | kirakira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kirakira
# Procesing record 260 | isangel.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=isangel
# Procesing record 261 | general roca.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=general%20roca
# Procesing record 262 | zorritos.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=zorritos
# Procesing record 263 | derzhavinsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=derzhavinsk
# Procesing record 264 | chernyshevskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chernyshevskiy
# Procesing record 265 | florianopolis.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=florianopolis
# Procesing record 266 | cayenne.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cayenne
# Procesing record 267 | amahai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=amahai
# Procesing record 268 | kiunga.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kiunga
# Procesing record 269 | santiago de cuba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=santiago%20de%20cuba
# Procesing record 270 | palmer.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=palmer
# Procesing record 271 | kodiak.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kodiak
# Procesing record 272 | alofi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=alofi
# Procesing record 273 | kavaratti.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kavaratti
# Procesing record 274 | nebug.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nebug
# Procesing record 275 | asosa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=asosa
# Procesing record 276 | aitape.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aitape
# Procesing record 277 | belfast.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=belfast
# Procesing record 278 | methven.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=methven
# Procesing record 279 | morrope.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=morrope
# Procesing record 280 | ormond beach.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ormond%20beach
# Procesing record 281 | vila franca do campo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vila%20franca%20do%20campo
# Procesing record 282 | oussouye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oussouye
# Procesing record 283 | pangnirtung.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pangnirtung
# Procesing record 284 | cabo san lucas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cabo%20san%20lucas
# Procesing record 285 | matara.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=matara
# Procesing record 286 | aklavik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aklavik
# Procesing record 287 | tual.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tual
# Procesing record 288 | tuatapere.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tuatapere
# Procesing record 289 | malchin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=malchin
# Procesing record 290 | nanpiao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nanpiao
# Procesing record 291 | mozarlandia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mozarlandia
# Procesing record 292 | dakar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dakar
# Procesing record 293 | sioux falls.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sioux%20falls
# Procesing record 294 | provideniya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=provideniya
# Procesing record 295 | severo-kurilsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=severo-kurilsk
# Procesing record 296 | gillette.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gillette
# Procesing record 297 | bosaso.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bosaso
# Procesing record 298 | saint-georges.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=saint-georges
# Procesing record 299 | mitsamiouli.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mitsamiouli
# Procesing record 300 | ancud.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ancud
# Procesing record 301 | naze.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=naze
# Procesing record 302 | mongo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mongo
# Procesing record 303 | minas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=minas
# Procesing record 304 | okhotsk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=okhotsk
# Procesing record 305 | vesoul.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vesoul
# Procesing record 306 | simao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=simao
# Procesing record 307 | leshukonskoye.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=leshukonskoye
# Procesing record 308 | lashio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lashio
# Procesing record 309 | deniliquin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=deniliquin
# Procesing record 310 | gamba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gamba
# Procesing record 311 | baruun-urt.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=baruun-urt
# Procesing record 312 | nampula.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nampula
# Procesing record 313 | chumikan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chumikan
# Procesing record 314 | pskov.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pskov
# Procesing record 315 | grand gaube.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=grand%20gaube
# Procesing record 316 | samarai.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=samarai
# Procesing record 317 | taitung.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=taitung
# Procesing record 318 | vestmannaeyjar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vestmannaeyjar
# Procesing record 319 | san ramon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20ramon
# Procesing record 320 | san quintin.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=san%20quintin
# Procesing record 321 | pinawa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pinawa
# Procesing record 322 | urengoy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=urengoy
# Procesing record 323 | loveland.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=loveland
# Procesing record 324 | yeppoon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yeppoon
# Procesing record 325 | bubaque.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bubaque
# Procesing record 326 | ostersund.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ostersund
# Procesing record 327 | tongchuan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tongchuan
# Procesing record 328 | balaipungut.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=balaipungut
# Procesing record 329 | dingle.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dingle
# Procesing record 330 | yaan.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=yaan
# Procesing record 331 | kumano.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kumano
# Procesing record 332 | makakilo city.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=makakilo%20city
# Procesing record 333 | lorengau.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lorengau
# Procesing record 334 | dieppe.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dieppe
# Procesing record 335 | marsa matruh.
# ...
# Procesing record 435 | port blair.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port%20blair
# Procesing record 436 | kahului.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kahului
# Procesing record 437 | turukhansk.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=turukhansk
# Procesing record 438 | aberdeen.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aberdeen
# Procesing record 439 | marystown.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=marystown
# Procesing record 440 | mankapur.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mankapur
# Procesing record 441 | sisimiut.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sisimiut
# Procesing record 442 | pershotravneve.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pershotravneve
# Procesing record 443 | dodge city.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dodge%20city
# Procesing record 444 | praia da vitoria.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=praia%20da%20vitoria
# Procesing record 445 | noumea.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=noumea
# Procesing record 446 | kaili.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaili
# Procesing record 447 | cleethorpes.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cleethorpes
# Procesing record 448 | najran.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=najran
# Procesing record 449 | gourdon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gourdon
# Procesing record 450 | vao.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=vao
# Procesing record 451 | ucluelet.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ucluelet
# Procesing record 452 | mpika.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mpika
# Procesing record 453 | sijunjung.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sijunjung
# Procesing record 454 | bozhou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bozhou
# Procesing record 455 | kilrush.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kilrush
# Procesing record 456 | flinders.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=flinders
# Procesing record 457 | xingyi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=xingyi
# Procesing record 458 | mount isa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mount%20isa
# Procesing record 459 | la fleche.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=la%20fleche
# Procesing record 460 | aubenas.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aubenas
# Procesing record 461 | tautira.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tautira
# Procesing record 462 | pontypridd.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pontypridd
# Procesing record 463 | tromso.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tromso
# Procesing record 464 | krasnooktyabrskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=krasnooktyabrskiy
# Procesing record 465 | nokaneng.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nokaneng
# Procesing record 466 | aguimes.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=aguimes
# Procesing record 467 | kupino.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kupino
# Procesing record 468 | oktyabrskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=oktyabrskiy
# Procesing record 469 | dzilam gonzalez.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=dzilam%20gonzalez
# Procesing record 470 | qandala.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=qandala
# Procesing record 471 | chivay.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chivay
# Procesing record 472 | mahdasht.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mahdasht
# Procesing record 473 | pudozh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pudozh
# Procesing record 474 | merrill.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=merrill
# Procesing record 475 | champerico.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=champerico
# Procesing record 476 | opuwo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=opuwo
# Procesing record 477 | mishkino.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mishkino
# Procesing record 478 | feni.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=feni
# Procesing record 479 | deputatskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=deputatskiy
# Procesing record 480 | katsuura.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=katsuura
# Procesing record 481 | senador canedo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=senador%20canedo
# Procesing record 482 | kachiry.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kachiry
# Procesing record 483 | poum.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=poum
# Procesing record 484 | kaniama.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kaniama
# Procesing record 485 | edd.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=edd
# Procesing record 486 | pochutla.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=pochutla
# Procesing record 487 | ippy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ippy
# Procesing record 488 | ossora.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ossora
# Procesing record 489 | klaksvik.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=klaksvik
# Procesing record 490 | anadyr.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=anadyr
# Procesing record 491 | gizo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=gizo
# Procesing record 492 | chimoio.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chimoio
# Procesing record 493 | sao miguel do araguaia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sao%20miguel%20do%20araguaia
# Procesing record 494 | beringovskiy.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=beringovskiy
# Procesing record 495 | livingston.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=livingston
# Procesing record 496 | awjilah.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=awjilah
# Procesing record 497 | binzhou.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=binzhou
# Procesing record 498 | guantanamo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=guantanamo
# Procesing record 499 | choix.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=choix
# Procesing record 500 | ngunguru.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ngunguru
# Procesing record 501 | lokosovo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lokosovo
# Procesing record 502 | itarema.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=itarema
# Procesing record 503 | nador.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=nador
# Procesing record 504 | sawtell.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sawtell
# Procesing record 505 | huarmey.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=huarmey
# Procesing record 506 | mangrol.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mangrol
# Procesing record 507 | basco.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=basco
# Procesing record 508 | christchurch.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=christchurch
# Procesing record 509 | thyolo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=thyolo
# Procesing record 510 | manaure.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=manaure
# Procesing record 511 | bon air.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=bon%20air
# Procesing record 512 | itoman.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=itoman
# Procesing record 513 | hovd.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hovd
# Procesing record 514 | mala.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=mala
# Procesing record 515 | college.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=college
# Procesing record 516 | linxia.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=linxia
# Procesing record 517 | ust-kulom.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=ust-kulom
# Procesing record 518 | guarapari.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=guarapari
# Procesing record 519 | hongjiang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hongjiang
# Procesing record 520 | moscow.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=moscow
# Procesing record 521 | kununurra.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kununurra
# Procesing record 522 | lebanon.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lebanon
# Procesing record 523 | payson.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=payson
# Procesing record 524 | sabang.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=sabang
# Procesing record 525 | coihaique.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=coihaique
# Procesing record 526 | broome.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=broome
# Procesing record 527 | hella.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=hella
# Procesing record 528 | tiznit.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=tiznit
# Procesing record 529 | great yarmouth.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=great%20yarmouth
# Procesing record 530 | chunoyar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=chunoyar
# Procesing record 531 | port-gentil.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=port-gentil
# Procesing record 532 | kharp.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=kharp
# Procesing record 533 | cordoba.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=cordoba
# Procesing record 534 | phalodi.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=phalodi
# Procesing record 535 | burley.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=burley
# Procesing record 536 | adrar.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=adrar
# Procesing record 537 | lasa.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lasa
# Procesing record 538 | koster.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=koster
# Procesing record 539 | isagarh.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=isagarh
# Procesing record 540 | svetlaya.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=svetlaya
# Procesing record 541 | inhambane.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=inhambane
# Procesing record 542 | jvari.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=jvari
# Procesing record 543 | lakes entrance.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=lakes%20entrance
# Procesing record 544 | progreso.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=progreso
# Procesing record 545 | porto novo.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=porto%20novo
# Procesing record 546 | craig.
# http://api.openweathermap.org/data/2.5/weather?appid=2541ce6d49e1e94f0f8e5690481f3a6e&units=metric&q=craig

# %%
d = pd.DataFrame()
d['City'] = cy
d['Cloudiness'] = cloud
d['Country'] = co
d['Date'] = date1
d['Humidity'] = hum
d['Lat'] = lat
d['Lng'] = long
d['Max Temp'] = xtemp
d['Wind Speed'] = ws

d.to_csv("output_data_file.csv", index=False)

# %%
d.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count   546.00000  5.460000e+02  546.000000  546.000000  546.000000
# mean     39.43956  1.550965e+09   75.851648   21.077216   20.198535
# std      35.76361  1.468690e+03   20.715858   32.728978   88.667697
# min       0.00000  1.550962e+09    0.000000  -54.810000 -179.170000
# 25%       0.00000  1.550963e+09   64.000000   -4.882500  -56.752500
# 50%      34.00000  1.550966e+09   80.500000   26.690000   22.630000
# 75%      75.00000  1.550966e+09   93.000000   48.255000   98.522500
# max     100.00000  1.550966e+09  100.000000   78.220000  179.320000
#
#          Max Temp  Wind Speed
# count  546.000000  546.000000
# mean    10.059414    3.544799
# std     15.931106    2.583209
# min    -43.260000    0.310000
# 25%      0.000000    1.500000
# 50%     13.320000    2.910000
# 75%     23.980000    4.897500
# max     36.000000   14.460000

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Max Temp']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")

# Save Figure

plt.savefig("City Latitude vs. Max Temperature 02232019.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Humidity']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")

# Save Figure

plt.savefig("City Latitude vs. Humidity 02232019.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Cloudiness']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

# Save Figure

plt.savefig("City Latitude vs. Cloudiness 02232019.png")

plt.show()

# %%
fig, ax = plt.subplots()

x_axis = d['Lat']
y_axis = d['Wind Speed']

plt.scatter(x_axis , y_axis, marker="o", facecolor="Aqua", edgecolors="black", alpha=0.90)

# Incorporate the other graph properties
ax.grid(True)

plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (Kph)")

# Save Figure

plt.savefig("City Latitude vs. Wind Speed 02232019.png")

plt.show()
